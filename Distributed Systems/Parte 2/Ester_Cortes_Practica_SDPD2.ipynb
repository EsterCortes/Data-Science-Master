# %% [markdown]
# # SISTEMAS DISTRIBUIDOS DE PROCESAMIENTOS DE DATOS 2
#
# ## PRÁCTICA FINAL T2
#
# ### AUTOR: Ester Cortés García

# %% [markdown]
# En esta primera parte de la práctica, se pide resolver los varios ejercicios utilizando un notebook
# de Jupyter con Spark SQL

# %% [markdown]
# ## Iniciar Spark

# %%
#import findspark
#findspark.init("/home/ester/spark/spark-2.2.1-bin-hadoop2.7")

import pyspark
from pyspark.sql import SparkSession
spark = (SparkSession.builder
    .master("local[*]")
    .config("spark.driver.cores", 1)
    .appName("understanding_sparksession")
    .getOrCreate() )
sc = spark.sparkContext
print(spark)
print(sc)
# Out:
# <pyspark.sql.session.SparkSession object at 0x7f1d0aa47748>
# <SparkContext master=local[*] appName=understanding_sparksession>

# %% [markdown]
# ## Definición del esquema

# %%
from pyspark.sql.types import *
#from pyspark.sql import functions
from pyspark.sql.functions import *
customSchema = StructType([StructField("Id", LongType(), True),
                           StructField("Parent_sys_id", StringType(), True),
                           StructField("Source", StringType(), True),
                           StructField("Mentions", StringType(), True),
                           StructField("Target", StringType(), True),
                           StructField("Name_source", StringType(), True),
                           StructField("Body", StringType(), True),
                           StructField("Pub_date", TimestampType(), True),
                           StructField("URLs", StringType(), True),
                           StructField("Tipe_action", StringType(), True),
                           StructField("Link", StringType(), True),
                           StructField("Has_link", ByteType(), True),
                           StructField("Has_picture", ByteType(), True),
                           StructField("Website", StringType(), True),
                           StructField("Country", StringType(), True),
                           StructField("Activity", LongType(), True),
                           StructField("Followers", LongType(), True),
                           StructField("Following", LongType(), True),
                           StructField("Location", StringType(), True)
                          ])

# %% [markdown]
# ## Carga de datos

# %%
events = spark.read.csv("/home/ester/spark/practica_sdpd2/DATASET-Twitter-23-26-Mar-2014-MotoGP-Qatar.csv",
                        header=True, schema=customSchema, timestampFormat="dd/MM/yyyy HH:mm")
                        #mode="FAILFAST") #

# %%
events.printSchema()
# Out:
# root
#  |-- Id: long (nullable = true)
#  |-- Parent_sys_id: string (nullable = true)
#  |-- Source: string (nullable = true)
#  |-- Mentions: string (nullable = true)
#  |-- Target: string (nullable = true)
#  |-- Name_source: string (nullable = true)
#  |-- Body: string (nullable = true)
#  |-- Pub_date: timestamp (nullable = true)
#  |-- URLs: string (nullable = true)
#  |-- Tipe_action: string (nullable = true)
#  |-- Link: string (nullable = true)
#  |-- Has_link: byte (nullable = true)
#  |-- Has_picture: byte (nullable = true)
#  |-- Website: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- Activity: long (nullable = true)
#  |-- Followers: long (nullable = true)
#  |-- Following: long (nullable = true)
#  |-- Location: string (nullable = true)

# %% [markdown]
# ## Ejercicios

# %% [markdown]
# ### Ejercicio 1
#
# Calcular el número total de tweets por usuario para los 150 usuarios con más mensajes en la muestra de tweets analizados. Calcular, para cada uno de estos usuarios la media de hashtags enviados por mensaje.
# (2.5 puntos)

# %%
# CONSULTA 1: Calcular el número total de tweets por usuario para los 150 usuarios con más mensajes.

(events.groupBy("Source")
     .agg(count("Id").alias("tweets"))
     .orderBy("tweets", ascending=False)
     .limit(150).collect())
# Out:
# [Row(Source='m_azharaji', tweets=486),
#  Row(Source='twitMOTOGP', tweets=401),
#  Row(Source='johnbokke', tweets=297),
#  Row(Source='qatarflights', tweets=283),
#  Row(Source='box_repsol', tweets=267),
#  Row(Source='yolandaa_95', tweets=185),
#  Row(Source='AlessiaPont', tweets=182),
#  Row(Source='MM93Lovers', tweets=169),
#  Row(Source='motomatters', tweets=169),
#  Row(Source='Sonic_Moto', tweets=165),
#  Row(Source='noelia_260797', tweets=157),
#  Row(Source='birtymotogp', tweets=155),
#  Row(Source='trackseven707', tweets=152),
#  Row(Source='crash_motogp', tweets=149),
#  Row(Source='pedrosistas', tweets=148),
#  Row(Source='MarcMarquezTeam', tweets=148),
#  Row(Source='MotoFamilyGP', tweets=144),
#  Row(Source='Kay46_MotoGP', tweets=142),
#  Row(Source='blogenboxes', tweets=133),
#  Row(Source='Ciintiia93', tweets=133),
#  Row(Source='JesiPacio', tweets=130),
#  Row(Source='tigrescuba', tweets=125),
#  Row(Source='VAVEL_motor', tweets=124),
#  Row(Source='MotoGPquotes', tweets=123),
#  Row(Source='thalia_26_', tweets=119),
#  Row(Source='plusmoto', tweets=119),
#  Row(Source='iNotaMental_', tweets=116),
#  Row(Source='Cev_Ford', tweets=115),
#  Row(Source='salo_98', tweets=113),
#  Row(Source='btsportmotogp', tweets=113),
#  Row(Source='AnaAlvarez9325', tweets=111),
#  Row(Source='kamseunyil', tweets=111),
#  Row(Source='Luciadp26', tweets=109),
#  Row(Source='Carlota_147', tweets=109),
#  Row(Source='keikokoeswadi', tweets=107),
#  Row(Source='FansHM_9323', tweets=107),
#  Row(Source='Paula_Bravo3', tweets=107),
#  Row(Source='rohimahfidia', tweets=105),
#  Row(Source='LiveMoto_GP', tweets=104),
#  Row(Source='RedGhostOnline', tweets=102),
#  Row(Source='AsyrafAye', tweets=102),
#  Row(Source='nisaauliarahma5', tweets=101),
#  Row(Source='unmontondruedas', tweets=101),
#  Row(Source='Jhoez7', tweets=100),
#  Row(Source='MartinoMoto', tweets=96),
#  Row(Source='MotoGP', tweets=95),
#  Row(Source='AkbarValeLorenz', tweets=93),
#  Row(Source='Miisael_Sound07', tweets=93),
#  Row(Source='Cantimoto3', tweets=92),
#  Row(Source='_montse24', tweets=92),
#  Row(Source='dani_lazaro4', tweets=91),
#  Row(Source='movistar_motogp', tweets=90),
#  Row(Source='14Azam', tweets=88),
#  Row(Source='deabruX', tweets=87),
#  Row(Source='MotoRaceFeed', tweets=87),
#  Row(Source='ERA_agustini93', tweets=86),
#  Row(Source='Moyettoh', tweets=84),
#  Row(Source='ArwikaYulenda', tweets=84),
#  Row(Source='merynebot', tweets=83),
#  Row(Source='fi_sonic', tweets=82),
#  Row(Source='RoberthStonem', tweets=82),
#  Row(Source='moto1pro', tweets=81),
#  Row(Source='FotoMotoGP', tweets=81),
#  Row(Source='Habraham15', tweets=80),
#  Row(Source='OFCMarcMarquez', tweets=78),
#  Row(Source='adelyellow46', tweets=78),
#  Row(Source='Silverstonecabs', tweets=78),
#  Row(Source='geroroldan', tweets=76),
#  Row(Source='RRRubenruizcasa', tweets=75),
#  Row(Source='dinaarifiani', tweets=75),
#  Row(Source='FORMULAMotoGP', tweets=73),
#  Row(Source='Arenita_58', tweets=72),
#  Row(Source='aryVR46', tweets=72),
#  Row(Source='GonzaloLausada', tweets=72),
#  Row(Source='febrero1991_26', tweets=72),
#  Row(Source='olle_pana', tweets=72),
#  Row(Source='tiefanovic', tweets=72),
#  Row(Source='zaramalik93', tweets=71),
#  Row(Source='MOTOaceleracion', tweets=71),
#  Row(Source='Noeliiia_93', tweets=70),
#  Row(Source='FAST_PICTURES', tweets=70),
#  Row(Source='hildangelina', tweets=69),
#  Row(Source='DesyAfrianti', tweets=69),
#  Row(Source='93MarquezFan', tweets=68),
#  Row(Source='Opapa69', tweets=68),
#  Row(Source='connor_swyer', tweets=68),
#  Row(Source='Ar_Sinyo', tweets=67),
#  Row(Source='EG_00', tweets=67),
#  Row(Source='Wyndha14', tweets=66),
#  Row(Source='Ally_93_12', tweets=66),
#  Row(Source='lalito4', tweets=65),
#  Row(Source='zaidasphyxiated', tweets=65),
#  Row(Source='motocuatro', tweets=64),
#  Row(Source='nisaauliarahma', tweets=64),
#  Row(Source='LaGrace82', tweets=64),
#  Row(Source='Esth3r_Bena', tweets=63),
#  Row(Source='Esther26_', tweets=63),
#  Row(Source='DayaQuir0s', tweets=63),
#  Row(Source='OraoctavianiB', tweets=62),
#  Row(Source='andylewis48', tweets=62),
#  Row(Source='farid__irfan', tweets=62),
#  Row(Source='HildaL0pez', tweets=61),
#  Row(Source='ArrancaMotores', tweets=61),
#  Row(Source='veromend3z', tweets=61),
#  Row(Source='DayaCamp0s', tweets=61),
#  Row(Source='vale_1114', tweets=61),
#  Row(Source='_fahrurrozi_', tweets=60),
#  Row(Source='MaryPattins0n', tweets=60),
#  Row(Source='__Th0r', tweets=60),
#  Row(Source='Lavinotintocom', tweets=60),
#  Row(Source='26_Fishy', tweets=60),
#  Row(Source='ColMotorFans', tweets=60),
#  Row(Source='Russ3ll_Mathy', tweets=60),
#  Row(Source='MarcMarquezFan_', tweets=60),
#  Row(Source='Gord0_Friki', tweets=59),
#  Row(Source='MariaL0b0', tweets=59),
#  Row(Source='Alice_Inferno', tweets=59),
#  Row(Source='Drivin4Pleasure', tweets=59),
#  Row(Source='CobMara', tweets=59),
#  Row(Source='Ryuzaky46', tweets=59),
#  Row(Source='MiniD0g', tweets=58),
#  Row(Source='alexavengas', tweets=58),
#  Row(Source='SmeraldaSmith', tweets=58),
#  Row(Source='marianav3ga', tweets=58),
#  Row(Source='vivanlasmotos', tweets=58),
#  Row(Source='ainoaaaaa95', tweets=58),
#  Row(Source='Mari_L0p3z', tweets=58),
#  Row(Source='_L4dy_Gaga', tweets=57),
#  Row(Source='Kathy_Monti3l', tweets=57),
#  Row(Source='motogepe_com', tweets=57),
#  Row(Source='DarkSpac3', tweets=57),
#  Row(Source='SianAdey_S_Hill', tweets=57),
#  Row(Source='DimeHilario', tweets=57),
#  Row(Source='Judith5Fdz', tweets=57),
#  Row(Source='nasyaafatharani', tweets=56),
#  Row(Source='Tom_Cruis3', tweets=56),
#  Row(Source='yuliadmy26', tweets=56),
#  Row(Source='Formula1chick', tweets=56),
#  Row(Source='ariviri27', tweets=56),
#  Row(Source='bahrum_s46', tweets=56),
#  Row(Source='motogp_fanpage', tweets=56),
#  Row(Source='PamelaBosqu3s', tweets=56),
#  Row(Source='Queenshee04', tweets=56),
#  Row(Source='KimberlyVillaV', tweets=56),
#  Row(Source='hicarltheprof', tweets=56),
#  Row(Source='Astrid_Swann', tweets=56),
#  Row(Source='Elena_Watts0n', tweets=55),
#  Row(Source='Martin_Fi3d', tweets=55),
#  Row(Source='MotoLines', tweets=55),
#  Row(Source='maria_lorenzo99', tweets=55)]

# %%
# CONSULTA 2: Calcular, para cada uno de estos usuarios la media de hashtags enviados por mensaje

# Se crea un dataframe con los 150 usuarios con más tweets (se podría coger el de la primera consulta pero, 
# para poder mostrarlo, he decidido volver a crearlo aquí y guardarlo en una variable)

users = (events.groupBy("Source")
             .agg(count("Id").alias("tweets"))
             .orderBy("tweets", ascending=False)
             .limit(150)
             .select("Source").collect())

# Se crea un array vacío donde se guardarán los nombres de los 150 usuarios

Users = []

for r in users:
    Users.append(str(r).replace("Row(Source='", "").replace("')",""))

# Nos quedamos del array original con aquellas filas cuyo usuario se encuentre en el array y se divide el contenido
# de la variable body

df_hashtags = (events.select("Id","Source","Body")
            .filter(events.Source.isin(Users))
            .select("Id","Source",split("Body",' ').alias("Words"))
            .select("Id","Source",explode("Words").alias("Hashtags")))

# Sobre el array, nos quedamos solo con las palabras del body que sean hashtags y procedemos a calcular el número 
# de tweets y el número medio de hashtags por tweet

(df_hashtags.filter(df_hashtags.Hashtags.startswith("#"))
         .groupBy("Source","Id")
         .agg(count("Source").alias("numberHashtags"))
         .groupBy("Source")
         .agg(mean("numberHashtags").alias("meanHashtags"))
         .orderBy("meanHashtags",ascending=False)
         .collect())
# Out:
# [Row(Source='MM93Lovers', meanHashtags=3.808641975308642),
#  Row(Source='twitMOTOGP', meanHashtags=3.302325581395349),
#  Row(Source='hicarltheprof', meanHashtags=2.872340425531915),
#  Row(Source='LiveMoto_GP', meanHashtags=2.5),
#  Row(Source='yolandaa_95', meanHashtags=2.4123711340206184),
#  Row(Source='EG_00', meanHashtags=2.263157894736842),
#  Row(Source='yuliadmy26', meanHashtags=2.210526315789474),
#  Row(Source='unmontondruedas', meanHashtags=2.193877551020408),
#  Row(Source='ArwikaYulenda', meanHashtags=2.1),
#  Row(Source='blogenboxes', meanHashtags=2.0714285714285716),
#  Row(Source='Tom_Cruis3', meanHashtags=2.0),
#  Row(Source='Martin_Fi3d', meanHashtags=2.0),
#  Row(Source='marianav3ga', meanHashtags=2.0),
#  Row(Source='MiniD0g', meanHashtags=2.0),
#  Row(Source='Silverstonecabs', meanHashtags=2.0),
#  Row(Source='Alice_Inferno', meanHashtags=2.0),
#  Row(Source='Mari_L0p3z', meanHashtags=2.0),
#  Row(Source='DarkSpac3', meanHashtags=2.0),
#  Row(Source='MaryPattins0n', meanHashtags=2.0),
#  Row(Source='Elena_Watts0n', meanHashtags=2.0),
#  Row(Source='alexavengas', meanHashtags=2.0),
#  Row(Source='KimberlyVillaV', meanHashtags=2.0),
#  Row(Source='veromend3z', meanHashtags=2.0),
#  Row(Source='Astrid_Swann', meanHashtags=2.0),
#  Row(Source='MariaL0b0', meanHashtags=2.0),
#  Row(Source='HildaL0pez', meanHashtags=2.0),
#  Row(Source='Esth3r_Bena', meanHashtags=2.0),
#  Row(Source='DayaCamp0s', meanHashtags=2.0),
#  Row(Source='DayaQuir0s', meanHashtags=2.0),
#  Row(Source='MartinoMoto', meanHashtags=2.0),
#  Row(Source='vale_1114', meanHashtags=2.0),
#  Row(Source='PamelaBosqu3s', meanHashtags=2.0),
#  Row(Source='LaGrace82', meanHashtags=2.0),
#  Row(Source='RoberthStonem', meanHashtags=2.0),
#  Row(Source='_L4dy_Gaga', meanHashtags=2.0),
#  Row(Source='Russ3ll_Mathy', meanHashtags=2.0),
#  Row(Source='CobMara', meanHashtags=2.0),
#  Row(Source='Gord0_Friki', meanHashtags=2.0),
#  Row(Source='Kathy_Monti3l', meanHashtags=2.0),
#  Row(Source='Jhoez7', meanHashtags=2.0),
#  Row(Source='SmeraldaSmith', meanHashtags=2.0),
#  Row(Source='Lavinotintocom', meanHashtags=2.0),
#  Row(Source='__Th0r', meanHashtags=2.0),
#  Row(Source='Cantimoto3', meanHashtags=1.9761904761904763),
#  Row(Source='andylewis48', meanHashtags=1.9411764705882353),
#  Row(Source='Opapa69', meanHashtags=1.9361702127659575),
#  Row(Source='OFCMarcMarquez', meanHashtags=1.9344262295081966),
#  Row(Source='FotoMotoGP', meanHashtags=1.9135802469135803),
#  Row(Source='fi_sonic', meanHashtags=1.9066666666666667),
#  Row(Source='thalia_26_', meanHashtags=1.8928571428571428),
#  Row(Source='olle_pana', meanHashtags=1.878787878787879),
#  Row(Source='MOTOaceleracion', meanHashtags=1.875),
#  Row(Source='AlessiaPont', meanHashtags=1.8666666666666667),
#  Row(Source='MotoFamilyGP', meanHashtags=1.8650793650793651),
#  Row(Source='RRRubenruizcasa', meanHashtags=1.8518518518518519),
#  Row(Source='motocuatro', meanHashtags=1.826086956521739),
#  Row(Source='Ally_93_12', meanHashtags=1.7894736842105263),
#  Row(Source='Paula_Bravo3', meanHashtags=1.7872340425531914),
#  Row(Source='Arenita_58', meanHashtags=1.763157894736842),
#  Row(Source='zaramalik93', meanHashtags=1.75),
#  Row(Source='26_Fishy', meanHashtags=1.736842105263158),
#  Row(Source='nisaauliarahma', meanHashtags=1.7297297297297298),
#  Row(Source='salo_98', meanHashtags=1.7272727272727273),
#  Row(Source='connor_swyer', meanHashtags=1.71875),
#  Row(Source='Carlota_147', meanHashtags=1.7142857142857142),
#  Row(Source='Luciadp26', meanHashtags=1.6956521739130435),
#  Row(Source='Sonic_Moto', meanHashtags=1.6944444444444444),
#  Row(Source='RedGhostOnline', meanHashtags=1.6857142857142857),
#  Row(Source='dinaarifiani', meanHashtags=1.68),
#  Row(Source='aryVR46', meanHashtags=1.6666666666666667),
#  Row(Source='Ryuzaky46', meanHashtags=1.6666666666666667),
#  Row(Source='lalito4', meanHashtags=1.6666666666666667),
#  Row(Source='DesyAfrianti', meanHashtags=1.6603773584905661),
#  Row(Source='Wyndha14', meanHashtags=1.6551724137931034),
#  Row(Source='Esther26_', meanHashtags=1.65),
#  Row(Source='box_repsol', meanHashtags=1.6490066225165563),
#  Row(Source='GonzaloLausada', meanHashtags=1.6428571428571428),
#  Row(Source='rohimahfidia', meanHashtags=1.6382978723404256),
#  Row(Source='vivanlasmotos', meanHashtags=1.6379310344827587),
#  Row(Source='kamseunyil', meanHashtags=1.6344086021505377),
#  Row(Source='FAST_PICTURES', meanHashtags=1.6304347826086956),
#  Row(Source='JesiPacio', meanHashtags=1.6296296296296295),
#  Row(Source='noelia_260797', meanHashtags=1.6282051282051282),
#  Row(Source='93MarquezFan', meanHashtags=1.625),
#  Row(Source='Judith5Fdz', meanHashtags=1.6153846153846154),
#  Row(Source='zaidasphyxiated', meanHashtags=1.6071428571428572),
#  Row(Source='moto1pro', meanHashtags=1.5822784810126582),
#  Row(Source='nasyaafatharani', meanHashtags=1.5625),
#  Row(Source='nisaauliarahma5', meanHashtags=1.5490196078431373),
#  Row(Source='dani_lazaro4', meanHashtags=1.5396825396825398),
#  Row(Source='FORMULAMotoGP', meanHashtags=1.5333333333333334),
#  Row(Source='AsyrafAye', meanHashtags=1.532258064516129),
#  Row(Source='febrero1991_26', meanHashtags=1.5185185185185186),
#  Row(Source='_montse24', meanHashtags=1.5172413793103448),
#  Row(Source='btsportmotogp', meanHashtags=1.488888888888889),
#  Row(Source='bahrum_s46', meanHashtags=1.4736842105263157),
#  Row(Source='Ciintiia93', meanHashtags=1.4705882352941178),
#  Row(Source='pedrosistas', meanHashtags=1.4705882352941178),
#  Row(Source='Ar_Sinyo', meanHashtags=1.4705882352941178),
#  Row(Source='farid__irfan', meanHashtags=1.4642857142857142),
#  Row(Source='Formula1chick', meanHashtags=1.4615384615384615),
#  Row(Source='MotoGPquotes', meanHashtags=1.4587155963302751),
#  Row(Source='hildangelina', meanHashtags=1.4482758620689655),
#  Row(Source='Noeliiia_93', meanHashtags=1.4473684210526316),
#  Row(Source='johnbokke', meanHashtags=1.4384615384615385),
#  Row(Source='movistar_motogp', meanHashtags=1.425),
#  Row(Source='merynebot', meanHashtags=1.4230769230769231),
#  Row(Source='Habraham15', meanHashtags=1.42),
#  Row(Source='Kay46_MotoGP', meanHashtags=1.3902439024390243),
#  Row(Source='motomatters', meanHashtags=1.3846153846153846),
#  Row(Source='ArrancaMotores', meanHashtags=1.3636363636363635),
#  Row(Source='adelyellow46', meanHashtags=1.36),
#  Row(Source='qatarflights', meanHashtags=1.3425414364640884),
#  Row(Source='AnaAlvarez9325', meanHashtags=1.3272727272727274),
#  Row(Source='ERA_agustini93', meanHashtags=1.3157894736842106),
#  Row(Source='MotoGP', meanHashtags=1.2923076923076924),
#  Row(Source='14Azam', meanHashtags=1.2769230769230768),
#  Row(Source='FansHM_9323', meanHashtags=1.2666666666666666),
#  Row(Source='MarcMarquezFan_', meanHashtags=1.2619047619047619),
#  Row(Source='Queenshee04', meanHashtags=1.2608695652173914),
#  Row(Source='_fahrurrozi_', meanHashtags=1.2553191489361701),
#  Row(Source='MotoRaceFeed', meanHashtags=1.2297297297297298),
#  Row(Source='MarcMarquezTeam', meanHashtags=1.2272727272727273),
#  Row(Source='ariviri27', meanHashtags=1.2142857142857142),
#  Row(Source='tigrescuba', meanHashtags=1.2048192771084338),
#  Row(Source='trackseven707', meanHashtags=1.1724137931034482),
#  Row(Source='deabruX', meanHashtags=1.1612903225806452),
#  Row(Source='OraoctavianiB', meanHashtags=1.1379310344827587),
#  Row(Source='ainoaaaaa95', meanHashtags=1.125),
#  Row(Source='SianAdey_S_Hill', meanHashtags=1.1219512195121952),
#  Row(Source='motogp_fanpage', meanHashtags=1.1071428571428572),
#  Row(Source='geroroldan', meanHashtags=1.105263157894737),
#  Row(Source='ColMotorFans', meanHashtags=1.1),
#  Row(Source='plusmoto', meanHashtags=1.0566037735849056),
#  Row(Source='MotoLines', meanHashtags=1.0392156862745099),
#  Row(Source='VAVEL_motor', meanHashtags=1.0229885057471264),
#  Row(Source='Drivin4Pleasure', meanHashtags=1.0196078431372548),
#  Row(Source='crash_motogp', meanHashtags=1.0096153846153846),
#  Row(Source='keikokoeswadi', meanHashtags=1.0095238095238095),
#  Row(Source='m_azharaji', meanHashtags=1.0041322314049588),
#  Row(Source='tiefanovic', meanHashtags=1.0),
#  Row(Source='Cev_Ford', meanHashtags=1.0),
#  Row(Source='AkbarValeLorenz', meanHashtags=1.0),
#  Row(Source='maria_lorenzo99', meanHashtags=1.0),
#  Row(Source='motogepe_com', meanHashtags=1.0)]

# %% [markdown]
# ### Ejercicio 2
#
# Calcular el número total de mensajes que contienen información de geolocalización en el campo LOCATION.
# (2.5 puntos)

# %%
# Se filtra el contenido de la variable location para quedarnos solo con aquellos cuyo contenido empieza por ÜT, 
# ya que en la ficha técnica pone que solo aquellos que tienen eso, contienen las coordenadas exactas

(events.select("Location").filter(events.Location.startswith('ÜT')).count())
# Out:
# 2136

# %% [markdown]
# ### Ejercicio 3
#
# Calcular las 5 cuentas de Twitter que más han sido mencionadas en todo el conjunto de datos analizados.
# (2.5 puntos)

# %%
# Para poder recoger las menciones será necesario quedarnos únicamente con aquellos tweets en los que se nos
# indique que hay una mención
(events.filter("Tipe_action == 'MT'")
     .select(split("Mentions", ',').alias("allUsers"))
     .select(explode("allUsers").alias("Users"))
     .groupBy("Users")
     .agg(count("Users").alias("countMentions"))
     .orderBy("countMentions", ascending=False)
     .limit(5).show())
# Out:
# +--------------+-------------+
# |         Users|countMentions|
# +--------------+-------------+
# |  valeyellow46|        19599|
# | marcmarquez93|        16826|
# |        motogp|         7770|
# |     lorenzo99|         6969|
# |26_danipedrosa|         3093|
# +--------------+-------------+

# %% [markdown]
# ### Ejercicio 4
#
# Calcular los 10 mensajes más retweeteados y los 10 mensajes que han acumulado más respuestas en la muestra de datos analizados. Ahora, restringe la búsqueda a los mensajes en el intervalo 2014-03-24 05:00 - 2014-03-24 11:00.
# (2.5 puntos)

# %% [markdown]
# Para esta consulta he dudado acerca de la interpretación, ya que considero que hay dos posibilidades:
# La primera es que, sobre los 10 tweets más retweeteados / con más respuestas, se aplica el intervalo para ver cuáles de ellos se produjeron en él.
# La segunda es que se sacan los 10 tweets más retweetedos / con más respuestas que estén dentro del intervalo indicado.

# %%
#PRIMERA INTERPRETACIÓN

# Esta consulta se divide en dos, una para los mensajes retweeteados y otra para los mensajes con más respuestas,
# ambas comparten la misma estructura y en lo único que se diferencian es en el tipo de acción, ya que para la 
# primera consulta nos quedamos con 'RT'y para la segunda 'MT' ('MT' porque cuando se responde un tweet,
# aparece el nombre del usuario al que se responde y, por lo tanto, existe una mención.)
# Nos quedamos con aquellos tweets que tengan padre, es decir, que no son el tweet original, sino que dependen
# de otro, agrupamos por el id del padre que será el tweet original y contamos. 
# Mediante una lista vacía nos quedamos con los id y luego, del dataframe completo, nos quedamos con aquellos
# tweets que se encuentren en la lista y que estén dentro del intervalo deseado. 

# 10 mensajes más retweeteados. En el intervalo temporal indicado solo hay una. 

retweets = (events.select("Parent_sys_id","Tipe_action")
             .filter("Parent_sys_id != 'sin padre'")
             .filter("Tipe_action == 'RT'")
             .groupBy("Parent_sys_id")
             .agg(count("Parent_sys_id").alias("countRetweets"))
             .orderBy("countRetweets",ascending=False)
             .limit(10)
             .select("Parent_sys_id").collect())    
        
Ids = []

for r in retweets:
    Ids.append(str(r).replace("Row(Parent_sys_id='", "").replace("')",""))

(events.select("Id",to_timestamp("Pub_date").alias("Date"),dayofmonth(to_timestamp("Pub_date")).alias("Day"),
                   hour(to_timestamp("Pub_date")).alias("Hour"))
     .filter("Day == 24")
     .filter("(Hour >= 5) AND (Hour < 11)")
     .filter(events.Id.isin(Ids))
     .drop("Day")
     .drop("Hour")
     .show())


# 10 mensajes con más respuestas. En el intervalo temporal indicado no hay ninguna

responses = (events.select("Parent_sys_id","Tipe_action")
             .filter("Parent_sys_id != 'sin padre'")
             .filter("Tipe_action == 'MT'")
             .groupBy("Parent_sys_id")
             .agg(count("Parent_sys_id").alias("countResponses"))
             .orderBy("countResponses",ascending=False)
             .limit(10))

Ids = []

for r in responses:
    Ids.append(str(r).replace("Row(Parent_sys_id='", "").replace("')",""))

(events.select("Id",to_timestamp("Pub_date").alias("Date"),dayofmonth(to_timestamp("Pub_date")).alias("Day"),
                   hour(to_timestamp("Pub_date")).alias("Hour"))
     .filter("Day == 24")
     .filter("(Hour >= 5) AND (Hour < 11)")
     .filter(events.Id.isin(Ids))
     .drop("Day")
     .drop("Hour")
     .show())
# Out:
# +------+-------------------+
# |    Id|               Date|
# +------+-------------------+
# |666385|2014-03-24 10:52:00|
# +------+-------------------+
#
# +---+----+
# | Id|Date|
# +---+----+
# +---+----+

# %%
# SEGUNDA INTERPRETACIÓN

# Esta consulta se divide en dos, una para los mensajes retweeteados y otra para los mensajes con más respuestas,
# ambas comparten la misma estructura y en lo único que se diferencian es en el tipo de acción, ya que para la 
# primera consulta nos quedamos con 'RT'y para la segunda 'MT' ('MT' porque cuando se responde un tweet,
# aparece el nombre del usuario al que se responde y, por lo tanto, existe una mención.)
# La estructura es similar a la de la primera interpretación pero se incluye el filtrado por hora y día en la 
# primera parte de la consulta, dejando de ser necesaria la segunda parte. 

# 10 mensajes más retweeteados 

(events.select("Parent_sys_id","Tipe_action",dayofmonth(to_timestamp("Pub_date")).alias("Day"),
                   hour(to_timestamp("Pub_date")).alias("Hour"))
         .filter("Parent_sys_id != 'sin padre'")
         .filter("Tipe_action == 'RT'")
         .filter("Day == 24")
         .filter("(Hour >= 5) AND (Hour < 11)")
         .drop("Day")
         .drop("Hour")
         .groupBy("Parent_sys_id")
         .agg(count("Parent_sys_id").alias("countRetweets"))
         .orderBy("countRetweets",ascending=False)
         .limit(10).show())    

# 10 mensajes con más respuestas

(events.select("Parent_sys_id","Tipe_action",dayofmonth(to_timestamp("Pub_date")).alias("Day"),
                   hour(to_timestamp("Pub_date")).alias("Hour"))
         .filter("Parent_sys_id != 'sin padre'")
         .filter("Tipe_action == 'MT'")
         .filter("Day == 24")
         .filter("(Hour >= 5) AND (Hour < 11)")
         .drop("Day")
         .drop("Hour")
         .groupBy("Parent_sys_id")
         .agg(count("Parent_sys_id").alias("countResponses"))
         .orderBy("countResponses",ascending=False)
         .limit(10).show())
# Out:
# +-------------+-------------+
# |Parent_sys_id|countRetweets|
# +-------------+-------------+
# |       603804|          474|
# |       645626|          445|
# |       638320|          390|
# |       666385|          305|
# |       645328|          222|
# |       605727|          165|
# |       622993|          148|
# |       635916|          147|
# |       553100|          101|
# |       645225|           97|
# +-------------+-------------+
#
# +-------------+--------------+
# |Parent_sys_id|countResponses|
# +-------------+--------------+
# |       603804|            63|
# |       605727|            54|
# |       666385|            28|
# |       664891|            16|
# |       645626|            14|
# |       645225|            14|
# |       645328|            13|
# |       626650|             9|
# |       622993|             8|
# |       579001|             7|
# +-------------+--------------+

# %% [markdown]
# ## The End

# %%
# Remember to stop SparkContext before shutting down this notebook
sc.stop()
